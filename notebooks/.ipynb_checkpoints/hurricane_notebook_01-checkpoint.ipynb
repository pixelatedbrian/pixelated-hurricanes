# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %matplotlib inline

from scipy import interpolate
from mpl_toolkits.basemap import Basemap
from mpl_toolkits.axes_grid1 import make_axes_locatable
from scipy.misc import imread

# %% [markdown]
# ### Read in the data and simple review of features in data
#
# * ** There's no feature for category/strength of the storm, which would be nice. Might be able to use Wind as a proxy though, but that seems to be percentile rather than raw speed **
# * ** Financial damage of a storm would be interesting too but that would really just depend more on the storm hitting something valuable than really indicating a super powerful storm **

# %%
data = pd.read_csv("../data/allstorms.csv")

# data dictionary
# N/A,Year,#,BB,BB,N/A,YYYY-MM-DD HH:MM:SS,N/A,deg_north,deg_east,kt,mb,N/A,%,%,N/A

data.loc[:,"Season"] = data.loc[:,"Season"].apply(lambda x: int(x))

map_image = imread("../data/north_america_edited.png")

# %%
fig, tx = plt.subplots()
tx.imshow(map_image, zorder=0)

# %%
data.tail()
# Out:
#            Serial_Num  Season  Num Basin Sub_basin    Name  \
# 196679  2016074S16137    2016    3    SP        EA  NONAME
# 196680  2016074S16137    2016    3    SP        EA  NONAME
# 196681  2016074S16137    2016    3    SP        EA  NONAME
# 196682  2016074S16137    2016    3    SP        EA  NONAME
# 196683  2016074S16137    2016    3    SP        EA  NONAME
#
#                    ISO_time Nature  Latitude  Longitude  Wind(WMO)  Pres(WMO)  \
# 196679  2016-03-15 06:00:00     NR    -15.50      137.9       25.0      999.0
# 196680  2016-03-15 12:00:00     NR    -15.60      138.4       25.0     1000.0
# 196681  2016-03-15 18:00:00     NR    -16.00      139.4       25.0      998.0
# 196682  2016-03-16 00:00:00     NR    -16.40      140.3       30.0      998.0
# 196683  2016-03-16 06:00:00     NR    -16.55      141.1       30.0      999.0
#
#        Center  Wind(WMO) Percentile  Pres(WMO) Percentile Track_type
# 196679    bom                10.794                22.926       main
# 196680    bom                10.794                16.735       main
# 196681    bom                10.794                25.747       main
# 196682    bom                24.615                25.747       main
# 196683    bom                24.615                22.926       main

# %% [markdown]
# `print data.loc[:,"Basin"].unique()
# array(['BB', ' SI', ' NA', ' EP', ' SP', ' WP', ' NI', ' SA'], dtype=object)
#                 ^      ^      ^      ^      ^      ^      ^`
#
# ### "Basin" column has spaces in the text, should strip these out to be more correct

# %%
print data.loc[:,"Basin"].unique()
# array(['BB', ' SI', ' NA', ' EP', ' SP', ' WP', ' NI', ' SA'], dtype=object)

data.loc[:, "Basin"] = data.loc[:, "Basin"].apply(lambda x: x.replace(" ", ""))

print data.loc[:,"Basin"].unique()
# ['BB' 'SI' 'NA' 'EP' 'SP' 'WP' 'NI' 'SA']

data_na = data[data.loc[:, "Basin"] == "NA"]

len(data_na)
# Out:
# [' SI' ' NA' ' EP' ' SP' ' WP' ' NI' ' SA']
# ['SI' 'NA' 'EP' 'SP' 'WP' 'NI' 'SA']
# 49035

# %%
data_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49035 entries, 35 to 196401
# Data columns (total 16 columns):
# Serial_Num              49035 non-null object
# Season                  49035 non-null int64
# Num                     49035 non-null int64
# Basin                   49035 non-null object
# Sub_basin               49035 non-null object
# Name                    49035 non-null object
# ISO_time                49035 non-null object
# Nature                  49035 non-null object
# Latitude                49035 non-null float64
# Longitude               49035 non-null float64
# Wind(WMO)               49035 non-null float64
# Pres(WMO)               49035 non-null float64
# Center                  49035 non-null object
# Wind(WMO) Percentile    49035 non-null float64
# Pres(WMO) Percentile    49035 non-null float64
# Track_type              49035 non-null object
# dtypes: float64(6), int64(2), object(8)
# memory usage: 6.4+ MB

# %% [markdown]
# ### Attempt to figure out tropical storm/hurricane category per row

# %%
def safsimpsonize(wind):
    '''
    Takes in wind speed
    
    Returns saffir-simpson hurricane category with 0 and -1 for tropical storm/depression
    which doesn't make perfect sense as scales go but this maintains categories but allows
    the model/visualization to detect when something is a tropical depression
    
    According to: https://en.wikipedia.org/wiki/Saffir%E2%80%93Simpson_scale
    
    Return:  Category:   Wind Speed Range: (mph, seriously?)
    5        Cat 5      157 <= v
    4        Cat 4      130 <= v < 157
    3        Cat 3      111 <= v < 130
    2        Cat 2      96 <= v < 111
    1        Cat 1      74 <= v < 96
    0        Storm      39 <= v < 74
    -1       Depression v < 39
    '''
    if wind >= 157:
        return 5
    elif wind >= 130:
        return 4
    elif wind >= 111:
        return 3
    elif wind >= 96:
        return 2
    elif wind >= 74:
        return 1
    elif wind >= 39:
        return 0
    else:
        return -1

# %%
data_na.loc[:,"saffir_simpson_cat"] = data_na["Wind(WMO)"].apply(lambda x: safsimpsonize(x))

# %%
data_na.loc[:,"saffir_simpson_cat"].unique()
# Out:
# array([ 1,  0,  2,  3,  4, -1,  5])

# %% [markdown]
# ### Make a list of dataframes for each year. Not very efficient but brute forcing it

# %%
years = []

for year in data.Season.unique():
    temp = data[data.Season == year]
    years.append(temp)
    
# get rid of a nan DataFrame
years.pop(0)
# Out:
#        Serial_Num  Season  Num Basin Sub_basin        Name  \
# 0   1848011S09080    1848    2    SI        MM  XXXX848003
# 1   1848011S09080    1848    2    SI        MM  XXXX848003
# 2   1848011S09080    1848    2    SI        MM  XXXX848003
# 3   1848011S09080    1848    2    SI        MM  XXXX848003
# 4   1848011S09080    1848    2    SI        MM  XXXX848003
# 5   1848011S09080    1848    2    SI        MM  XXXX848003
# 6   1848011S09080    1848    2    SI        MM  XXXX848003
# 7   1848011S09080    1848    2    SI        MM  XXXX848003
# 8   1848011S09080    1848    2    SI        MM  XXXX848003
# 9   1848011S09080    1848    2    SI        MM  XXXX848003
# 10  1848011S09080    1848    2    SI        MM  XXXX848003
# 11  1848011S15057    1848    3    SI        MM  XXXX848002
# 12  1848011S15057    1848    3    SI        MM  XXXX848002
# 13  1848011S15057    1848    3    SI        MM  XXXX848002
# 14  1848011S15057    1848    3    SI        MM  XXXX848002
# 15  1848011S15057    1848    3    SI        MM  XXXX848002
# 16  1848011S15057    1848    3    SI        MM  XXXX848002
# 17  1848061S12075    1848    5    SI        MM  XXXX848001
# 18  1848061S12075    1848    5    SI        MM  XXXX848001
# 19  1848061S12075    1848    5    SI        MM  XXXX848001
# 20  1848061S12075    1848    5    SI        MM  XXXX848001
# 21  1848061S12075    1848    5    SI        MM  XXXX848001
# 22  1848061S12075    1848    5    SI        MM  XXXX848001
# 23  1848061S12075    1848    5    SI        MM  XXXX848001
#
#                ISO_time Nature  Latitude  Longitude  Wind(WMO)  Pres(WMO)  \
# 0   1848-01-11 06:00:00     NR      -8.6       79.8        0.0        0.0
# 1   1848-01-12 06:00:00     NR      -9.0       78.9        0.0        0.0
# 2   1848-01-13 06:00:00     NR     -10.4       73.2        0.0        0.0
# 3   1848-01-14 06:00:00     NR     -12.8       69.9        0.0        0.0
# 4   1848-01-15 06:00:00     NR     -13.9       68.9        0.0        0.0
# 5   1848-01-16 06:00:00     NR     -15.3       67.7        0.0        0.0
# 6   1848-01-17 06:00:00     NR     -16.5       67.0        0.0        0.0
# 7   1848-01-18 06:00:00     NR     -18.0       67.4        0.0        0.0
# 8   1848-01-19 06:00:00     NR     -20.6       69.8        0.0        0.0
# 9   1848-01-20 06:00:00     NR     -22.8       72.0        0.0        0.0
# 10  1848-01-21 06:00:00     NR     -27.2       75.8        0.0        0.0
# 11  1848-01-11 06:00:00     NR     -15.2       57.4        0.0        0.0
# 12  1848-01-12 06:00:00     NR     -15.8       56.6        0.0        0.0
# 13  1848-01-13 06:00:00     NR     -20.3       49.9        0.0        0.0
# 14  1848-01-14 06:00:00     NR     -26.1       46.7        0.0        0.0
# 15  1848-01-15 06:00:00     NR     -33.2       50.4        0.0        0.0
# 16  1848-01-16 06:00:00     NR     -34.1       51.1        0.0        0.0
# 17  1848-03-01 06:00:00     NR     -11.4       75.5        0.0        0.0
# 18  1848-03-02 06:00:00     NR     -11.7       74.0        0.0        0.0
# 19  1848-03-03 06:00:00     NR     -14.4       64.6        0.0        0.0
# 20  1848-03-04 06:00:00     NR     -17.6       57.6        0.0        0.0
# 21  1848-03-05 06:00:00     NR     -24.5       56.5        0.0        0.0
# 22  1848-03-06 06:00:00     NR     -29.6       59.9        0.0        0.0
# 23  1848-03-07 06:00:00     NR     -34.5       69.3        0.0        0.0
#
#      Center  Wind(WMO) Percentile  Pres(WMO) Percentile Track_type
# 0   reunion                -100.0                -100.0       main
# 1   reunion                -100.0                -100.0       main
# 2   reunion                -100.0                -100.0       main
# 3   reunion                -100.0                -100.0       main
# 4   reunion                -100.0                -100.0       main
# 5   reunion                -100.0                -100.0       main
# 6   reunion                -100.0                -100.0       main
# 7   reunion                -100.0                -100.0       main
# 8   reunion                -100.0                -100.0       main
# 9   reunion                -100.0                -100.0       main
# 10  reunion                -100.0                -100.0       main
# 11  reunion                -100.0                -100.0       main
# 12  reunion                -100.0                -100.0       main
# 13  reunion                -100.0                -100.0       main
# 14  reunion                -100.0                -100.0       main
# 15  reunion                -100.0                -100.0       main
# 16  reunion                -100.0                -100.0       main
# 17  reunion                -100.0                -100.0       main
# 18  reunion                -100.0                -100.0       main
# 19  reunion                -100.0                -100.0       main
# 20  reunion                -100.0                -100.0       main
# 21  reunion                -100.0                -100.0       main
# 22  reunion                -100.0                -100.0       main
# 23  reunion                -100.0                -100.0       main

# %% [markdown]
# ### Get all of the storms from a year

# %%
years[0]

storms = []

for storm in years[0].loc[:,"Serial_Num"].unique():
    storms.append(years[0][years[0].Serial_Num == storm])

# %%
storms[0].head()
# Out:
#        Serial_Num  Season  Num Basin Sub_basin        Name  \
# 24  1851080S15063    1851    2    SI        MM  XXXX851006
# 25  1851080S15063    1851    2    SI        MM  XXXX851006
# 26  1851080S15063    1851    2    SI        MM  XXXX851006
# 27  1851080S15063    1851    2    SI        MM  XXXX851006
# 28  1851080S15063    1851    2    SI        MM  XXXX851006
#
#                ISO_time Nature  Latitude  Longitude  Wind(WMO)  Pres(WMO)  \
# 24  1851-03-21 06:00:00     NR     -15.1       62.5        0.0        0.0
# 25  1851-03-22 06:00:00     NR     -15.9       61.0        0.0        0.0
# 26  1851-03-23 06:00:00     NR     -16.8       59.0        0.0        0.0
# 27  1851-03-24 06:00:00     NR     -17.1       57.0        0.0        0.0
# 28  1851-03-25 06:00:00     NR     -17.4       54.6        0.0        0.0
#
#      Center  Wind(WMO) Percentile  Pres(WMO) Percentile Track_type
# 24  reunion                -100.0                -100.0      split
# 25  reunion                -100.0                -100.0      split
# 26  reunion                -100.0                -100.0      split
# 27  reunion                -100.0                -100.0      split
# 28  reunion                -100.0                -100.0      split

# %% [markdown]
# ### Seems like working for the single year 1849

# %%
fig, ax = plt.subplots(figsize=(12,8))

for storm in storms:

    _lat = storm.Latitude.apply(lambda x: float(x))
    _long = storm.Longitude.apply(lambda x: float(x))


    ax.plot(_long, _lat, alpha=0.2, lw=2, color="blue")

# %% [markdown]
# ### Convert into an annual process that loops over the years

# %%
# # establish the figure
# fig, ax = plt.subplots(figsize=(12,8))

# ax.set_title("North American Hurricane Tracks Since 1849", size=20)
# ax.set_xlabel("Longitude", size=16)
# ax.set_ylabel("Latitude", size=16)
# ax.set_facecolor("black")
# ax.set_xlim(-110.0, -20.0)
# ax.set_ylim(0, 50.0)

# make a list for the years
years = []

# step through the Seasons (years) and make a new dataframe for each one
for year in data_na.loc[:, "Season"].unique():
    temp = data_na[data_na.loc[:, "Season"] == year]
    years.append(temp)
    
# get rid of a nan DataFrame
years.pop(0)

#loop through years in future gif
start = 164 - (2016 - 2000)
end = 164 - (2016 - 2016)

print start, end

print "total years", len(years)

#how many historical years
trailing_years = 0

# max window size in years
yr_window = 3

for idz, layer in enumerate(years[start:end]):
    
    # establish the figure
    fig, ax = plt.subplots(figsize=(20,14))

    _year = str(layer.loc[:, "Season"].unique()[0])
    
    ax.imshow(map_image, extent=[-110, -20, 0, 50],zorder=0)
    ax.set_title("North American Hurricane Tracks " + _year, size=20)
    ax.set_xlabel("Longitude", size=16)
    ax.set_ylabel("Latitude", size=16)
    ax.set_facecolor("black")
    ax.set_xlim(-110.0, -20.0)
    ax.set_ylim(0, 50.0)
    
    current_year_index = start + idz
    
    if trailing_years < yr_window:
        trailing_years+=1

    # step through each year
    # step through backwards so the newest year is idx=0 and has the highest alpha
    for idx, year in enumerate(years[current_year_index:current_year_index - trailing_years:-1]):
        # make a temp list to hold the storm dataframes from a single year
        storms = []

#         this_year = str(year.loc[:, "Season"].unique()[0])
#         print "year", this_year

        # step through the year and make a dataframe for each storm
        for storm in year.loc[:,"Serial_Num"].unique():
            storms.append(year[year.loc[:, "Serial_Num"] == storm])

        # now have a list of storm dataframes



        # step through all of the storms and add their tracks to the map
        for idy, storm in enumerate(storms):

    #         print "Working on year: {:4d} storm: {:4d}".format(idx, idy)

            _lat = storm.Latitude.apply(lambda x: float(x))
            _long = storm.Longitude.apply(lambda x: float(x))
    #         _cat = storm.loc[:, "saffir_simpson_cat"].apply(lambda x: float(20.0)**(x/2.0))
            _width = (storm.loc[:, "saffir_simpson_cat"] + 2)
            _colors = storm.loc[:,"Wind(WMO)"].apply(lambda x: x / 165.0)

            if len(_lat) < 10:
                pass
            else:
                # try some crazy interpolation stuff

                # Generate some random data
        #         y = (np.random.random(10) - 0.5).cumsum()
                x = np.arange(len(_lat))

                # Interpolate the data using a cubic spline to "new_length" samples
                new_length = 20 * len(_lat)

                # figure out length of new arrays
                new_x = np.linspace(x.min(), x.max(), new_length)

                # actually do the interpolation
                new_lat = interpolate.interp1d(x, _lat, kind='cubic')(new_x)
                new_long = interpolate.interp1d(x, _long, kind='cubic')(new_x)
                new_width = interpolate.interp1d(x, _width, kind='cubic')(new_x)
                new_colors = interpolate.interp1d(x, _colors, kind='cubic')(new_x)


        #         ax.fill_between(_long, _lat - _width/2.0, _lat + _width/2.0, alpha=0.5, color="blue")
        #         ax.plot(_long, _lat, alpha=0.05, lw=_width, color="blue")
                ax.scatter(new_long, new_lat, alpha=0.1 / (5 * idx**3 + 1), s=new_width * 100 / (idx + 1), c=new_colors, cmap='inferno', zorder=idy+1)
# Out:
# 148 164
# total years 164

# %%
x = np.arange(0, 10)
y = np.exp(-x/3.0)
f = interpolate.interp1d(x, y)

xnew = np.arange(0, 9, 0.1)
ynew = f(xnew)   # use interpolation function returned by `interp1d`

# %%
print y
print
print ynew
print
print f
# Out:
# [ 1.          0.71653131  0.51341712  0.36787944  0.26359714  0.1888756
#   0.13533528  0.09697197  0.06948345  0.04978707]
#
# [ 1.          0.97165313  0.94330626  0.91495939  0.88661252  0.85826566
#   0.82991879  0.80157192  0.77322505  0.74487818  0.71653131  0.69621989
#   0.67590847  0.65559705  0.63528563  0.61497421  0.5946628   0.57435138
#   0.55403996  0.53372854  0.51341712  0.49886335  0.48430958  0.46975582
#   0.45520205  0.44064828  0.42609451  0.41154074  0.39698698  0.38243321
#   0.36787944  0.35745121  0.34702298  0.33659475  0.32616652  0.31573829
#   0.30531006  0.29488183  0.2844536   0.27402537  0.26359714  0.25612498
#   0.24865283  0.24118068  0.23370852  0.22623637  0.21876422  0.21129206
#   0.20381991  0.19634776  0.1888756   0.18352157  0.17816754  0.17281351
#   0.16745947  0.16210544  0.15675141  0.15139738  0.14604335  0.14068932
#   0.13533528  0.13149895  0.12766262  0.12382629  0.11998996  0.11615363
#   0.11231729  0.10848096  0.10464463  0.1008083   0.09697197  0.09422312
#   0.09147426  0.08872541  0.08597656  0.08322771  0.08047886  0.07773001
#   0.07498115  0.0722323   0.06948345  0.06751381  0.06554417  0.06357454
#   0.0616049   0.05963526  0.05766562  0.05569598  0.05372634  0.05175671]
#
# <scipy.interpolate.interpolate.interp1d object at 0x7faeb86089f0>

# %%
# # establish the figure
# fig, ax = plt.subplots(figsize=(12,8))

# ax.set_title("North American Hurricane Tracks Since 1849", size=20)
# ax.set_xlabel("Longitude", size=16)
# ax.set_ylabel("Latitude", size=16)
# ax.set_facecolor("black")
# ax.set_xlim(-110.0, -20.0)
# ax.set_ylim(0, 50.0)

# make a list for the years
years = []

# step through the Seasons (years) and make a new dataframe for each one
for year in data_na.loc[:, "Season"].unique():
    temp = data_na[data_na.loc[:, "Season"] == year]
    years.append(temp)
    
# get rid of a nan DataFrame
years.pop(0)

#loop through years in future gif
start = 164 - (2016 - 2014)
end = 164 - (2016 - 2016)

print start, end

print "total years", len(years)

#how many historical years
trailing_years = 0

# max window size in years
yr_window = 3

for idz, year in enumerate(years[start:end]):
    
    # establish the figure
    fig, ax = plt.subplots(figsize=(10,6))

    _year = str(year.loc[:, "Season"].unique()[0])
    
    data = np.linspace(165.0, 0, 10000).reshape(100,100)
#     data = np.clip(randn(250, 250), -1, 1)

    histo_image = ax.imshow(data, interpolation='nearest', cmap="inferno")
    
    divider = make_axes_locatable(ax)
    
    cax = divider.append_axes("right", size="2%", pad=0.05)

    # Add colorbar, make sure to specify tick locations to match desired ticklabels
    cbar = fig.colorbar(histo_image, ticks=[157, 130, 111, 96, 74, 39, 0], cax=cax)
    cbar.ax.set_yticklabels(['5^', '4^', '3^', '2^', '1^', 'T.S.^', 'T.D.^'])  # vertically oriented colorbar
    
    ax.imshow(map_image, extent=[-120, -20, 0, 50],zorder=0)
    ax.set_title("North American Hurricane Tracks " + _year, size=20)
    ax.set_xlabel("Longitude", size=16)
    ax.set_ylabel("Latitude", size=16)
    ax.set_facecolor("black")
    ax.set_xlim(-120.0, -20.0)
    ax.set_ylim(0, 50.0)
    
    # make a temp list to hold the storm dataframes from a single year
    storms = []

#         this_year = str(year.loc[:, "Season"].unique()[0])
#         print "year", this_year

    # step through the year and make a dataframe for each storm
    for storm in year.loc[:,"Serial_Num"].unique():
        storms.append(year[year.loc[:, "Serial_Num"] == storm])

    # now have a list of storm dataframes



    # step through all of the storms and add their tracks to the map
    for idy, storm in enumerate(storms):

#         print "Working on year: {:4d} storm: {:4d}".format(idx, idy)

        _lat = storm.Latitude.apply(lambda x: float(x))
        _long = storm.Longitude.apply(lambda x: float(x))
#         _cat = storm.loc[:, "saffir_simpson_cat"].apply(lambda x: float(20.0)**(x/2.0))
        _width = (storm.loc[:, "saffir_simpson_cat"] + 2) * 50
        _colors = storm.loc[:,"Wind(WMO)"].apply(lambda x: x / 165.0)

        if len(_lat) < 10:
            pass
        else:
            # try some crazy interpolation stuff

            # Generate some random data
    #         y = (np.random.random(10) - 0.5).cumsum()
            x = np.arange(len(_lat))

            # Interpolate the data using a cubic spline to "new_length" samples
            new_length = 20 * len(_lat)

            # figure out length of new arrays
            new_x = np.linspace(x.min(), x.max(), new_length)

            # actually do the interpolation
            new_lat = interpolate.interp1d(x, _lat, kind='cubic')(new_x)
            new_long = interpolate.interp1d(x, _long, kind='cubic')(new_x)
            new_width = interpolate.interp1d(x, _width, kind='cubic')(new_x)
            new_colors = interpolate.interp1d(x, _colors, kind='cubic')(new_x)


    #         ax.fill_between(_long, _lat - _width/2.0, _lat + _width/2.0, alpha=0.5, color="blue")
    #         ax.plot(_long, _lat, alpha=0.05, lw=_width, color="blue")
            ax.scatter(new_long, new_lat, alpha=0.1, s=new_width, c=new_colors, cmap='inferno')
# Out:
# 162 164
# total years 164

# %% [markdown]
# ### Make a small track per storm incrementally so it can be animated on a per storm basis

# %%
def make_diagram(year_df):
    '''
    do all of the stuff for the graphics of making a hurricane plot
    
    takes in the year dataframe in order to get the necessary data
    
    returns ax which is the figure axis that the current hurricane track will be added upon
    '''
        # establish the figure
    figure, axis = plt.subplots(figsize=(19.2,12.00), dpi=100)

    _year = str(year_df.loc[:, "Season"].unique()[0])
    
    data = np.linspace(165.0, 0, 10000).reshape(100,100)
#     data = np.clip(randn(250, 250), -1, 1)

    histo_image = axis.imshow(data, interpolation='nearest', cmap="inferno")
    
    divider = make_axes_locatable(axis)
    
    cax = divider.append_axes("right", size="2%", pad=0.05)

    # Add colorbar, make sure to specify tick locations to match desired ticklabels
    cbar = figure.colorbar(histo_image, ticks=[157, 130, 111, 96, 74, 39, 0], cax=cax)
    cbar.ax.set_yticklabels(['5^', '4^', '3^', '2^', '1^', 'T.S.^', 'T.D.^'])  # vertically oriented colorbar
    
    axis.imshow(map_image, extent=[-120, -30, 0, 50],zorder=0)
    axis.set_title("North American Hurricane Tracks " + _year, size=20)
    axis.set_xlabel("Longitude", size=16)
    axis.set_ylabel("Latitude", size=16)
    axis.set_facecolor("black")
    axis.set_xlim(-120.0, -30.0)
    axis.set_ylim(0, 50.0)
    
    return figure, axis

# %%
# make a list for the years
years = []

# step through the Seasons (years) and make a new dataframe for each one
for year in data_na.loc[:, "Season"].unique():
    temp = data_na[data_na.loc[:, "Season"] == year]
    years.append(temp)
    
# get rid of a nan DataFrame
years.pop(0)

#loop through years in future gif
start = 164 - (2016 - 2004)
end = 164 - (2016 - 2005)

print start, end

print "total years", len(years)

#how many historical years
trailing_years = 0

# max window size in years
yr_window = 3

for idz, year in enumerate(years[start:end]):
    
    # make a temp list to hold the storm dataframes from a single year
    storms = []
    
    # figure out what the year is
    _year = year.loc[:, "Season"].unique()[0]
    
    # start a new frame count for each year
    frame_count = 0

#         this_year = str(year.loc[:, "Season"].unique()[0])
#         print "year", this_year

    # step through the year and make a dataframe for each storm
    for storm in year.loc[:,"Serial_Num"].unique():
        storms.append(year[year.loc[:, "Serial_Num"] == storm])

    # now have a list of storm dataframes



    # step through all of the storms and add their tracks to the map
    for idy, storm in enumerate(storms):
        # old place to make diagram
        
        _lat = storm.Latitude.apply(lambda x: float(x))
        _long = storm.Longitude.apply(lambda x: float(x))
#         _cat = storm.loc[:, "saffir_simpson_cat"].apply(lambda x: float(20.0)**(x/2.0))
        _width = (storm.loc[:, "saffir_simpson_cat"] + 2) * 150
        _colors = storm.loc[:,"Wind(WMO)"].apply(lambda x: x / 165.0)
        

        # if the track has a very small number of data points then skip it
        if len(_lat) < 10:
            pass
        else:
            # try some crazy interpolation stuff

            x = np.arange(len(_lat))

            # Interpolate the data using a cubic spline to "new_length" samples
            # going from daily intervals to (interpolated) hourly
            new_length = 24 * len(_lat)

            # figure out length of new arrays
            new_x = np.linspace(x.min(), x.max(), new_length)

            # actually do the interpolation
            new_lat = interpolate.interp1d(x, _lat, kind='cubic')(new_x)
            new_long = interpolate.interp1d(x, _long, kind='cubic')(new_x)
            new_width = interpolate.interp1d(x, _width, kind='cubic')(new_x)
            new_colors = interpolate.interp1d(x, _colors, kind='cubic')(new_x)
            
            # convert colors from float to rgba using colormap
            new_colors = cm.inferno(new_colors)
            
            # set trail duration, maybe 3 days which 24 ticks per day is 72
            track_length = 24
            
            # figure out number of frames for the track
            frames = new_length // track_length
            
            # figure out the number of leftover extra frames to use all steps
            left_over_frames = new_length % track_length
            
            a_line = np.linspace(0.1, 0, left_over_frames)[::-1].reshape(1, left_over_frames)
            
            # frame calculated stuff
            t_long = new_long[:left_over_frames]
            t_lat = new_lat[:left_over_frames]
            t_width = new_width[:left_over_frames]
            t_colors = new_colors[:left_over_frames]
            
            # fix t_color alpha's with a_line alphas
            t_colors[:,3] = a_line
            
#             print "a_line.shape", a_line.shape
#             print "t_color.shape", t_color.shape
            
            fig, ax = make_diagram(year)
            
            ax.scatter(t_long, t_lat, s=t_width, c=t_colors)
            
            # for loop for each frame
            for frame in range(frames):      
                # print the year_storm_frame for practice for the file name saving
                _filename = "{:0>4}{:0>6}.png".format(_year, frame_count)
                _path = "../imgs/" + _filename
                
                # time window start:
                _ts = track_length * frame
                
                # time window end:
                _te = track_length * (frame + 1)
                
                a_line = np.linspace(1.0, 0, _te).reshape(1, _te)
            
                # frame calculated stuff
                t_long = new_long[: _te][::-1]
                t_lat = new_lat[: _te][::-1]
                t_width = new_width[: _te][::-1]
                t_colors = new_colors[: _te][::-1]

                # fix t_color alpha's with a_line alphas
                t_colors[:,3] = a_line

                fig, ax = make_diagram(year)
                ax.scatter(t_long, t_lat, s=t_width, c=t_colors)
                
                print "Saving {:>15}".format(_filename)
                fig.savefig(_path)
                plt.close("all")
                frame_count += 1
                

#     #         ax.fill_between(_long, _lat - _width/2.0, _lat + _width/2.0, alpha=0.5, color="blue")
#     #         ax.plot(_long, _lat, alpha=0.05, lw=_width, color="blue")
#             ax.scatter(new_long, new_lat, alpha=0.1, s=new_width, c=new_colors, cmap='inferno')
# Saving  2004000500.png
# Saving  2004000501.png
# Saving  2004000502.png
# Saving  2004000503.png
# Saving  2004000504.png
# Saving  2004000505.png
# Saving  2004000506.png
# Saving  2004000507.png
# Saving  2004000508.png
# Saving  2004000509.png
# Saving  2004000510.png
# Saving  2004000511.png
# Saving  2004000512.png
# Saving  2004000513.png
# Saving  2004000514.png
# Saving  2004000515.png
# Saving  2004000516.png
# Saving  2004000517.png
# Saving  2004000518.png
# Saving  2004000519.png
# Saving  2004000520.png
# Saving  2004000521.png
# Saving  2004000522.png
# Saving  2004000523.png
# Saving  2004000524.png
# Saving  2004000525.png
# Saving  2004000526.png
# Saving  2004000527.png
# Saving  2004000528.png
# Saving  2004000529.png
# Saving  2004000530.png
# Saving  2004000531.png
# Saving  2004000532.png
# Saving  2004000533.png
# Saving  2004000534.png
# Saving  2004000535.png
# Saving  2004000536.png
# Saving  2004000537.png
# Saving  2004000538.png
# Saving  2004000539.png
# Saving  2004000540.png
# Saving  2004000541.png
# Saving  2004000542.png
# Saving  2004000543.png
# Saving  2004000544.png
# Saving  2004000545.png
# Saving  2004000546.png
# Saving  2004000547.png
# Saving  2004000548.png
# Saving  2004000549.png
# Saving  2004000550.png
# Saving  2004000551.png
# Saving  2004000552.png
# Saving  2004000553.png
# Saving  2004000554.png
# Saving  2004000555.png
# Saving  2004000556.png
# Saving  2004000557.png
# Saving  2004000558.png
# Saving  2004000559.png
# Saving  2004000560.png
# Saving  2004000561.png
# Saving  2004000562.png
# Saving  2004000563.png
# Saving  2004000564.png
# Saving  2004000565.png
# Saving  2004000566.png
# Saving  2004000567.png
# Saving  2004000568.png
# Saving  2004000569.png
# Saving  2004000570.png
# Saving  2004000571.png
# Saving  2004000572.png
# Saving  2004000573.png
# Saving  2004000574.png
# Saving  2004000575.png
# Saving  2004000576.png
# Saving  2004000577.png
# Saving  2004000578.png
# Saving  2004000579.png
# Saving  2004000580.png
# Saving  2004000581.png
# Saving  2004000582.png
# Saving  2004000583.png
# Saving  2004000584.png
# Saving  2004000585.png
# Saving  2004000586.png
# Saving  2004000587.png
# Saving  2004000588.png
# Saving  2004000589.png
# Saving  2004000590.png
# Saving  2004000591.png
# Saving  2004000592.png
# Saving  2004000593.png
# Saving  2004000594.png

# %%
fig, bx = plt.subplots(figsize=(8,8))

data = np.linspace(165.0, 0, 10000).reshape(100,100)
#     data = np.clip(randn(250, 250), -1, 1)

bx.imshow(data, interpolation='nearest', cmap="inferno")


# Add colorbar, make sure to specify tick locations to match desired ticklabels
# cbar = fig.colorbar(histo_image, ticks=[157, 130, 111, 96, 74, 39, 0], cax=cax)
# cbar.ax.set_yticklabels(['5^', '4^', '3^', '2^', '1^', 'T.S.^', 'T.D.^'])  # vertically oriented colorbar
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-57942ba86d08> in <module>()
#       8
#       9
# ---> 10 cax = divider.append_axes("right", size="2%", pad=0.05)
#      11
#      12 # Add colorbar, make sure to specify tick locations to match desired ticklabels
#
# NameError: name 'divider' is not defined
